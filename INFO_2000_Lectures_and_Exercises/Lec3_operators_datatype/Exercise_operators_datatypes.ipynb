# %% [markdown]
# ## Exercise 1
# 1. Assign 18, "numbers", and 12.5 to three variables and print their datatypes
# 2. Use formatted printing and the three variables assigned above to print out: " 18 and 12.5 are numbers"
# 3. For the above variables cast the float to integer, the string to bool, and the integer to string.
# 4. Compare 'games' and 'Games' using the equality operator to see if they are equal and print out the boolean result of the comparison with a helpful message.
# 5. In a new cell, perform the following assignment, name = Einstein. Why doesn't it work? Add a comment in your code explaining why.

# %%
a = 18
b = ('numbers')
c = 12.5
print(type(a))
print(type(b))
print(type(c))
print(str(a) + ' and ' + str(c) + ' are ' + b)
num1 = int(c)
string = bool(b)
num2 = str(a)
word1 = 'games'
word2 = 'Games'
results = (word1 == word2)
print('Are ' + word1 + ' and ' + word2 + ' equal? -> ' + str(results))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# 18 and 12.5 are numbers
# Are games and Games equal? -> False

# %%
name = Einstein #It doesn't work because Einstien is not a defined variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 name = Einstein #It doesn't work because
#
# NameError: name 'Einstein' is not defined

# %% [markdown]
# ## Exercise 2
# Assign e = 2.71828, x = 2, y = 1.5 and z = 4. Without using the math library, calculate the following:
# - $\frac{\sqrt{z}}{y} + x $
# -  $(x + y)^2$
# - $e^{(-2x(y+x))}$

# %%
e = 2.71828
x = 2
y = 1.5
z = 4
exercise1 = (z**0.5)/y + x
exercise2 = (x + y)**2
exercise3 = e**(-2*x*(y + x))
print(exercise1)
print(exercise2)
print(exercise3)
# Out:
# 3.333333333333333
# 12.25
# 8.315365497611809e-07

# %% [markdown]
# ## Exercise 3
# The Body Mass Index or BMI is calculated using the following formula:
# $\textbf{BMI} = \frac{\text{Weight in Kilograms}}{\text{Height in Meters} \times \text{Height in Meters}} $
# Write a program that asks the user for their height in inches, and weight in pounds and prints out their BMI. Note, you will need to convert the user inputs to metric units.

# %%
height_in = float(input('What is your height in inches?'))
weight_lb = float(input('What is your weight in pounds?'))

height_m = height_in * 0.0254
weight_kg = weight_lb * 0.453

BMI = weight_kg/(height_m*height_m)

print('Your BMI is: ', BMI)
# Out:
# What is your height in inches? 62
# What is your weight in pounds? 140
# Your BMI is:  25.57263179042487

# %% [markdown]
# ## Exercise 4
# Write a program that asks the user for the coefficients (a,b, and c) of a quadratic equation and computes and prints out the root (x) using the following formula:
# $ ax^2+bx+c=0 \implies x=\frac{-b \pm \sqrt{b^2-4ac}}{2a}$

# %%
a = float(input('What is your coefficient for a?'))
b = float(input('What is your coefficient for b?'))
c = float(input('What is your coefficient for c?'))

descrim = b**2 - 4*a*c

# Calculate roots
x1 = (-b + descrim**0.5) / (2*a)
x2 = (-b - descrim**0.5) / (2*a)

# Print result
print("x =", x1)
print("x =", x2)
# Out:
# What is your coefficient for a? 1
# What is your coefficient for b? -3
# What is your coefficient for c? 2
# x = 2.0
# x = 1.0
